# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests
def shopee(item:str,by:str):
    by='Sold'
    if by not in ['Sold','Total Sold','Price','Rating','Number 5 Star Ratings','Total Number of Ratings']:
        print('Please spell correctly as either Sold, Total Sold, Price,Rating, Number 5 Star Ratings, Total Number of Ratings')
    name, sold, historical_sold, price, price_max, rating, rating_5, rating_4, total_number_rating,official, brand, link=[],[],[],[],[],[],[],[],[],[],[],[]
    shopee_url = 'https://shopee.sg/'
    keyword_search = item
    headers = {
    'User-Agent': 'Chrome',
    'Referer': '{}search?keyword={}'.format(shopee_url, keyword_search)
    }
    #URL to display base on keyword search and limit to 100 listings
    url = f'{shopee_url}api/v2/search_items/?by=relevancy&keyword={keyword_search}&limit=100&newest=0&order=desc&page_type=search'

    # Shopee API request
    r = requests.get(url,headers=headers).json()
    for i in r['items']:
        name.append(i['name'])
        sold.append(i['sold'])
        historical_sold.append(i['historical_sold'])
        price.append(i['price']/100000)
        price_max.append(i['price_max']/100000)
        rating.append(i['item_rating']['rating_star'])
        rating_5.append(i['item_rating']['rating_count'][5])
        rating_4.append(i['item_rating']['rating_count'][4])
        total_number_rating.append(i['item_rating']['rating_count'][0])
        official.append(i['is_official_shop'])
        brand.append(i['brand'])
        shop=i['shopid']
        item=i['itemid']
        # print(f'{shopee_url}product-i.{i['shopid']}')
        link.append(f'{shopee_url}product-i.{shop}.{item}')
    df = pd.DataFrame(name, columns=['Name'])
    df['Sold'] = sold
    df['Total Sold'] = historical_sold
    df['Price'] = price
    df['Price_max'] = price_max
    df['Rating']=rating
    df['Number 5 Star Ratings']=rating_5
    df['Number 4 Star Ratings']=rating_4
    df['Total Number of Ratings']=total_number_rating
    df['Official Shop']=official
    df['Brand']=brand
    df['Link']=link
    df.sort_values(by,ascending=False)
    df.to_excel('Shopee_products.xlsx',index=False)
    print('Success! :)')
    return

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests

by='Rating'

name, sold, historical_sold, price, price_max, rating, rating_5, rating_4, total_number_rating,official, brand, link=[],[],[],[],[],[],[],[],[],[],[],[]
shopee_url = 'https://shopee.sg/'
keyword_search = 'electric shaver'
headers = {
'User-Agent': 'Chrome',
'Referer': '{}search?keyword={}'.format(shopee_url, keyword_search)
}
#URL to display base on keyword search and limit to 100 listings
url = f'{shopee_url}api/v2/search_items/?by=relevancy&keyword={keyword_search}&limit=100&newest=0&order=desc&page_type=search'

# Shopee API request
r = requests.get(url,headers=headers).json()
for i in r['items']:
    name.append(i['name'])
    sold.append(i['sold'])
    historical_sold.append(i['historical_sold'])
    price.append(i['price']/100000)
    price_max.append(i['price_max']/100000)
    rating.append(i['item_rating']['rating_star'])
    rating_5.append(i['item_rating']['rating_count'][5])
    rating_4.append(i['item_rating']['rating_count'][4])
    total_number_rating.append(i['item_rating']['rating_count'][0])
    official.append(i['is_official_shop'])
    brand.append(i['brand'])
    shop=i['shopid']
    item=i['itemid']
    # print(f'{shopee_url}product-i.{i['shopid']}')
    link.append(f'{shopee_url}product-i.{shop}.{item}')
df = pd.DataFrame(name, columns=['Name'])
df['Sold'] = sold
df['Total Sold'] = historical_sold
df['Price'] = price
df['Price_max'] = price_max
df['Rating']=rating
df['Number 5 Star Ratings']=rating_5
df['Number 4 Star Ratings']=rating_4
df['Total Number of Ratings']=total_number_rating
df['Official Shop']=official
df['Brand']=brand
df['Link']=link
df=df.sort_values(by=by,ascending=False)
df
# Out:
#                                                  Name  Sold  Total Sold  \
# 75  (Eetmo) 4D Rotary Men Electric Shaver Recharge...     0          13
# 25  Philips Shaver Series 9000 Wet and Dry Electri...     1           1
# 78                 Philips Electric Shaver - PQ206/18     4           7
# 49  [Ready Stock]4 Heads Painless Lady Shaver Hair...     3           3
# 48  Philips S1121 Wet or Dry Electric Shaver. Comf...    12          16
# ..                                                ...   ...         ...
# 70  Electric shaver male washing razor 6D multi-fu...     2           7
# 65  4 in 1 Rechargeable Shaver & Trimmer for Hair ...    16         176
# 77  Philips Shaver Series 9000 Shaving Heads - SH9...     3          17
# 35  Braun Series 3 Electric Shaver ★ 300S / 310S  ...     1          71
# 93  Philips 1000 Series Electric Shaver S1232 /Dry...     0           0
#
#      Price  Price_max    Rating  Number 5 Star Ratings  Number 4 Star Ratings  \
# 75   22.47      22.47  5.000000                      4                      0
# 25  299.00     299.00  5.000000                      1                      0
# 78   35.00      35.00  5.000000                      4                      0
# 49    5.00      12.60  5.000000                      3                      0
# 48   35.88      35.88  5.000000                     12                      0
# ..     ...        ...       ...                    ...                    ...
# 70   12.00      21.00  4.500000                      3                      0
# 65   14.90      14.90  4.476190                     45                      9
# 77   95.00      95.00  4.333333                      5                      0
# 35   47.90      59.90  4.333333                     19                      1
# 93   93.69      93.69  0.000000                      0                      0
#
#     Total Number of Ratings  Official Shop          Brand  \
# 75                        4          False              0
# 25                        1           True           None
# 78                        4           True           None
# 49                        3          False           None
# 48                       12          False           None
# ..                      ...            ...            ...
# 70                        4          False  MY Collection
# 65                       63          False          Kemei
# 77                        6           True        Philips
# 35                       27          False          Braun
# 93                        0          False           None
#
#                                                  Link
# 75   https://shopee.sg/product-i.152973898.7702302169
# 25   https://shopee.sg/product-i.414088011.2937535029
# 78   https://shopee.sg/product-i.414088011.9835399080
# 49  https://shopee.sg/product-i.152076496.10816768156
# 48    https://shopee.sg/product-i.74232609.9560454285
# ..                                                ...
# 70   https://shopee.sg/product-i.427770820.9448206284
# 65   https://shopee.sg/product-i.165040849.9015663281
# 77   https://shopee.sg/product-i.414088011.9736865429
# 35   https://shopee.sg/product-i.151556698.6948377550
# 93  https://shopee.sg/product-i.471991384.11915503816
#
# [100 rows x 12 columns]

# %%
df=df.sort_values('Price_max',ascending=False)
df
# Out:
#                                                  Name  Sold  Total Sold  \
# 62  Philips Shaver S9000 Prestige Wet & dry electr...     0          13
# 56  Philips Shaver Series 9000 Wet and Dry Electri...     0          12
# 25  Philips Shaver Series 9000 Wet and Dry Electri...     1           1
# 29  Philips Shaver Series 9000 Efficient and Preci...     3           4
# 23  Philips Shaver series 6000 Wet and Dry Electri...     0          22
# ..                                                ...   ...         ...
# 61  3 in 1 Shaver Hair Trimmer Rechargeable Kemei ...    81         767
# 98  Electric Mini Nose Hair Trimmer Portable Ear N...    11          38
# 99  Kemei Male Rechargeable Hair Clipper Electric ...     0          74
# 47  XPREEN Electric Shaving Nose Ear Hair Trimmer ...    19        2748
# 91  220V RSCW-A28 Portable Electric Rechargeable R...     2          93
#
#      Price  Price_max    Rating  Number 5 Star Ratings  Number 4 Star Ratings  \
# 62  599.00     599.00  5.000000                      4                      0
# 56  459.00     459.00  5.000000                      7                      0
# 25  299.00     299.00  5.000000                      1                      0
# 29  259.00     259.00  5.000000                      1                      0
# 23  229.00     229.00  5.000000                      7                      0
# ..     ...        ...       ...                    ...                    ...
# 61    9.92       9.92  4.711599                    272                     23
# 98    8.90       8.90  4.952381                     20                      1
# 99    8.88       8.88  4.657143                     27                      6
# 47    3.99       7.49  4.794773                    917                     66
# 91    7.02       7.02  4.687500                     39                      6
#
#     Total Number of Ratings  Official Shop     Brand  \
# 62                        4           True   Philips
# 56                        7           True         0
# 25                        1           True      None
# 29                        1           True      None
# 23                        7           True   Philips
# ..                      ...            ...       ...
# 61                      319          False  No Brand
# 98                       21          False  No Brand
# 99                       35          False     Kemei
# 47                     1034          False    Xpreen
# 91                       48          False         0
#
#                                                 Link
# 62   https://shopee.sg/product-i.22800308.2809800352
# 56    https://shopee.sg/product-i.22800308.323765693
# 25  https://shopee.sg/product-i.414088011.2937535029
# 29  https://shopee.sg/product-i.414088011.9636865573
# 23   https://shopee.sg/product-i.22800308.2184937485
# ..                                               ...
# 61   https://shopee.sg/product-i.81190082.5534165954
# 98  https://shopee.sg/product-i.197257954.9531232467
# 99  https://shopee.sg/product-i.132826017.1997175674
# 47    https://shopee.sg/product-i.48834674.770945279
# 91   https://shopee.sg/product-i.81106830.1417309406
#
# [100 rows x 12 columns]

# %%
df
# Out:
#                                                  Name  Sold  Total Sold  \
# 1               Braun Mobile Shave M 30 Pocket Shaver   106        3217
# 8   🌟 SG Seller 4 in 1 Men's 6D Electric Shaver Ha...   101        1002
# 61  3 in 1 Shaver Hair Trimmer Rechargeable Kemei ...    81         767
# 46  3 in 1 Shaver Hair Trimmer Rechargeable Kemei ...    81         767
# 6         PHILIPS S1121/41 Wet or Dry Electric Shaver    69         515
# ..                                                ...   ...         ...
# 72  CkeyiN Men Electric Shaver Reciprocating Foil ...     0          16
# 62  Philips Shaver S9000 Prestige Wet & dry electr...     0          13
# 63  2020 Xiami Mijia Electric Shaver S500C 3 In 1 ...     0          15
# 22  Braun 3-Series  310s 300s Rechargeable Wet&Dry...     0          96
# 99  Kemei Male Rechargeable Hair Clipper Electric ...     0          74
#
#      Price  Price_max    Rating  Number 5 Star Ratings  Number 4 Star Ratings  \
# 1    26.00      26.00  4.850330                   1233                     86
# 8    13.90      13.90  4.714660                    322                     29
# 61    9.92       9.92  4.711599                    272                     23
# 46    9.92       9.92  4.711599                    272                     23
# 6    42.00      42.00  4.899123                    214                      9
# ..     ...        ...       ...                    ...                    ...
# 72   14.60      14.60  4.857143                      6                      1
# 62  599.00     599.00  5.000000                      4                      0
# 63   73.99      73.99  5.000000                      6                      0
# 22   69.90      69.90  4.880952                     38                      3
# 99    8.88       8.88  4.657143                     27                      6
#
#     Total Number of Ratings  Official Shop     Brand  \
# 1                      1363           True         0
# 8                       383          False  No Brand
# 61                      319          False  No Brand
# 46                      319          False  No Brand
# 6                       228          False
# ..                      ...            ...       ...
# 72                        7           True      None
# 62                        4           True   Philips
# 63                        6          False
# 22                       42          False         0
# 99                       35          False     Kemei
#
#                                                 Link
# 1     https://shopee.sg/product-i.20175892.287128534
# 8    https://shopee.sg/product-i.88696854.3741109057
# 61   https://shopee.sg/product-i.81190082.5534165954
# 46   https://shopee.sg/product-i.81190082.5534165954
# 6    https://shopee.sg/product-i.30447185.6416232910
# ..                                               ...
# 72   https://shopee.sg/product-i.43704589.1583087850
# 62   https://shopee.sg/product-i.22800308.2809800352
# 63    https://shopee.sg/product-i.1702198.3538297334
# 22   https://shopee.sg/product-i.51942426.2589898689
# 99  https://shopee.sg/product-i.132826017.1997175674
#
# [100 rows x 12 columns]
